# %%
import pandas as pd


df=pd.read_csv(r'C:\Users\sraje\Code\SavvyCoders\Capstone\Nutrition__Physical_Activity__and_Obesity_-_Behavioral_Risk_Factor_Surveillance_System.csv')

# %%
df.head(5)
# Out:
#    YearStart  YearEnd LocationAbbr LocationDesc Datasource  \
# 0       2011     2011           AK       Alaska      BRFSS
# 1       2011     2011           AK       Alaska      BRFSS
# 2       2011     2011           AK       Alaska      BRFSS
# 3       2011     2011           AK       Alaska      BRFSS
# 4       2011     2011           AK       Alaska      BRFSS
#
#                      Class                         Topic  \
# 0  Obesity / Weight Status       Obesity / Weight Status
# 1  Obesity / Weight Status       Obesity / Weight Status
# 2        Physical Activity  Physical Activity - Behavior
# 3  Obesity / Weight Status       Obesity / Weight Status
# 4  Obesity / Weight Status       Obesity / Weight Status
#
#                                             Question  Data_Value_Unit  \
# 0  Percent of adults aged 18 years and older who ...           2011.0
# 1  Percent of adults aged 18 years and older who ...           2011.0
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of         YearStart  YearEnd LocationAbbr LocationDesc Datasource  \
# 0            2011     2011           AK       Alaska      BRFSS
# 1            2011     2011           AK       Alaska      BRFSS
# 2            2011     2011           AK       Alaska      BRFSS
# 3            2011     2011           AK       Alaska      BRFSS
# 4            2011     2011           AK       Alaska      BRFSS
# ...           ...      ...          ...          ...        ...
# 104267       2023     2023           WY      Wyoming      BRFSS
# 104268       2023     2023           WY      Wyoming      BRFSS
# 104269       2023     2023           WY      Wyoming      BRFSS
# 104270       2023     2023           WY      Wyoming      BRFSS
# 104271       2023     2023           WY      Wyoming      BRFSS
#
#                           Class                         Topic  \
# 0       Obesity / Weight Status       Obesity / Weight Status
# ...

# %%
# df.head(5)
df.shape
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 104272 entries, 0 to 104271
# Data columns (total 33 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   YearStart                   104272 non-null  int64
#  1   YearEnd                     104272 non-null  int64
#  2   LocationAbbr                104272 non-null  object
#  3   LocationDesc                104272 non-null  object
#  4   Datasource                  104272 non-null  object
#  5   Class                       104272 non-null  object
#  6   Topic                       104272 non-null  object
#  7   Question                    104272 non-null  object
#  8   Data_Value_Unit             88872 non-null   float64
#  9   Data_Value_Type             104272 non-null  object
#  10  Data_Value                  93505 non-null   float64
#  11  Data_Value_Alt              93505 non-null   float64
# ...

# %%
df.duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 104267    False
# 104268    False
# 104269    False
# 104270    False
# 104271    False
# Length: 104272, dtype: bool

# %%
# Filter only obesity-related questions
df_ques = df['Question'].unique()
df_ques
# Out:
# array(['Percent of adults aged 18 years and older who have obesity',
#        'Percent of adults who achieve at least 150 minutes a week of moderate-intensity aerobic physical activity or 75 minutes a week of vigorous-intensity aerobic physical activity and engage in muscle-strengthening activities on 2 or more days a week',
#        'Percent of adults aged 18 years and older who have an overweight classification',
#        'Percent of adults who engage in muscle-strengthening activities on 2 or more days a week',
#        'Percent of adults who achieve at least 300 minutes a week of moderate-intensity aerobic physical activity or 150 minutes a week of vigorous-intensity aerobic activity (or an equivalent combination)',
#        'Percent of adults who engage in no leisure-time physical activity',
# ...

# %%
# Proper list of column names (cleaned up)
columns_needed = [
    'YearStart', 'LocationAbbr', 'LocationDesc',
    'Topic', 'Question', 'Data_Value',
    'Age(years)', 'Education', 'Sex', 'Income', 'Race/Ethnicity'
]
# Filter the DataFrame
df_filtered3 = df[columns_needed]

# Show top 5 rows
df_filtered3.head(5)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19272\633182394.py in ?()
#       9
#      10 # Show top 5 rows
#      11 df_filtered3.head(5)
#      12
# ---> 13 df_sexcleaned=df_cleaned = df.dropna(subset=['sex'])
#      14
#      15
#
# c:\Users\sraje\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py in ?(self, axis, how, thresh, subset, inplace, ignore_index)
#    6666             ax = self._get_axis(agg_axis)
#    6667             indices = ax.get_indexer_for(subset)
#    6668             check = indices == -1
#    6669             if check.any():
# -> 6670                 raise KeyError(np.array(subset)[check].tolist())
#    6671             agg_obj = self.take(indices, axis=agg_axis)
#    6672
#    6673         if thresh is not lib.no_default:
#
# KeyError: ['sex']

# %%
df_sexcleaned= df_filtered3.dropna(subset=['Sex'])
df_sexcleaned.shape
df_sexcleaned.head(5)

df_year=df_sexcleaned['YearStart']
df_year.unique()
# Out:
# array([2011, 2016, 2012, 2015, 2013, 2014, 2017, 2018, 2019, 2020, 2021,
#        2022, 2023])

# %%
df_ques = df['Question'].unique()
df_ques

# %%
df1=pd.read_csv(r'C:\Users\sraje\Code\SavvyCoders\Capstone\Grocery_Customer_Churn_Data.csv')
df1.info()
df1.shape
df1.head(5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35843 entries, 0 to 35842
# Data columns (total 28 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   customer_id               35843 non-null  object
#  1   age                       35843 non-null  int64
#  2   gender                    35843 non-null  object
#  3   income_bracket            35843 non-null  object
#  4   loyalty_program           35843 non-null  object
#  5   membership_years          35843 non-null  int64
#  6   marital_status            35843 non-null  object
#  7   number_of_children        35843 non-null  int64
#  8   education_level           35843 non-null  object
#  9   occupation                35843 non-null  object
#  10  transaction_id            35843 non-null  object
#  11  transaction_date          35843 non-null  object
#  12  product_category          35843 non-null  object
# ...

# %%
df2=pd.read_csv(r'C:\Users\sraje\Code\SavvyCoders\Capstone\Electric_Vehicle_Population_Data.csv')
df2.info()
df2.shape
df2.head(5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 247344 entries, 0 to 247343
# Data columns (total 17 columns):
#  #   Column                                             Non-Null Count   Dtype
# ---  ------                                             --------------   -----
#  0   VIN (1-10)                                         247344 non-null  object
#  1   County                                             247340 non-null  object
#  2   City                                               247340 non-null  object
#  3   State                                              247344 non-null  object
#  4   Postal Code                                        247340 non-null  float64
#  5   Model Year                                         247344 non-null  int64
#  6   Make                                               247344 non-null  object
#  7   Model                                              247344 non-null  object
# ...

# %%
import pandas as pd 
df3=pd.read_excel(r'C:\Users\sraje\Code\SavvyCoders\Capstone\CPS MDCR ENROLL AB 1-8 2021.xlsx')
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 2 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Total Medicare Enrollment  9 non-null      object
#  1   Unnamed: 1                 9 non-null      object
# dtypes: object(2)
# memory usage: 276.0+ bytes

# %%
df4=pd.read_csv(r'C:\Users\sraje\Code\SavvyCoders\Capstone\LakeCounty_Health_-6177935595181947989.csv')
df4.info()
df4.shape
df4.head(5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   OBJECTID       52 non-null     int64
#  1   NAME           52 non-null     object
#  2   Obesity        52 non-null     float64
#  3   Shape__Area    51 non-null     float64
#  4   Shape__Length  51 non-null     float64
# dtypes: float64(3), int64(1), object(1)
# memory usage: 2.2+ KB
#    OBJECTID        NAME  Obesity   Shape__Area  Shape__Length
# 0         1       Texas     32.4  7.672329e+12   1.540832e+07
# 1         2  California     24.2  5.327809e+12   1.451870e+07
# 2         3    Kentucky     34.6  1.128830e+12   6.346699e+06
# 3         4     Georgia     30.7  1.652980e+12   5.795596e+06
# 4         5   Wisconsin     30.7  1.567816e+12   6.806782e+06

# %%
df5=pd.read_csv(r'C:\Users\sraje\Code\SavvyCoders\Capstone\Nutrition__Physical_Activity__and_Obesity_-_Youth_Risk_Behavior_Surveillance_System.csv')
df5.info()
df5.shape
df5.head(5)
df5.['age']
# Out:
#   Cell In[2], line 5
#     df5.['age']
#         ^
# SyntaxError: invalid syntax
